# %% [markdown]
# #### imports

# %%
import pandas as pd
import os

# %% [markdown]
# #### load data

# %%
data_path = r"..\data"

# %% [markdown]
# #### mfcc

# %%
mfcc_path = data_path + r"\mfcc.csv"
mfcc_data = pd.read_csv(mfcc_path)
mfcc_data.head()
# Out:
#                  id    MFCC000    MFCC001    MFCC002   MFCC003   MFCC004  \
# 0  9EPCgcAlXdgiFsx4  20.640961  -5.828413  -6.140859  2.526664 -1.409552
# 1  9epP1yOXfLKlkR3S  24.351542 -16.611490 -10.792922  0.983246 -4.003687
# 2  9EPSUhPoRVOFU3WZ  20.963654 -10.754437 -17.771996  4.075799 -7.670935
# 3  9eQ9CI53RilCiWe1  23.706192  -6.617346  -0.802629 -7.173328 -7.087190
# 4  9eQBXVI9m9OVpOzk  23.435280 -15.198643 -15.216316  6.386479 -1.970684
#
#     MFCC005   MFCC006    MFCC007   MFCC008  ...  cov_10_12   cov_11_11  \
# 0  2.681575 -2.989035   6.298501  3.528709  ...  -4.037570  120.298222
# 1 -0.180248 -1.510487  -0.663130  2.915891  ...   2.551358   55.188890
# 2  7.884864  6.939635  -0.451056  1.786007  ...   4.270046   92.649081
# 3  1.222832  0.271057   5.402615 -1.984503  ...  -0.670753   92.840371
# 4  2.223027  3.663818  10.492731  3.448581  ... -10.117312   70.432960
#
#    cov_11_12  cov_12_12              genre  popularity  release  \
# ...

# %%
mfcc_data.shape
# Out:
# (109269, 111)

# %% [markdown]
# #### music_nn

# %%
musicnn_path = data_path + r"\musicnn.csv"
musicnn_data = pd.read_csv(musicnn_path)
musicnn_data.head()
# Out:
#                  id         0         1         2         3         4  \
# 0  0009fFIM1eYThaPg  0.055225  0.001055  0.015216  0.301295  0.007372
# 1  0010xmHR6UICBOYT  0.090460  0.004675  0.244330  0.185277  0.006459
# 2  002Jyd0vN4HyCpqL  0.249110  0.111420  0.023323  0.072560  0.146912
# 3  006TYKNjNxWjfKjy  0.195338  0.107382  0.101820  0.023141  0.109134
# 4  007LIJOPQ4Sb98qV  0.322574  0.006046  0.026422  0.009654  0.004463
#
#           5         6         7         8  ...        46        47        48  \
# 0  0.121369  0.205030  0.114958  0.144303  ...  0.008268  0.002438  0.104358
# 1  0.218079  0.271902  0.014446  0.021707  ...  0.002906  0.000388  0.002674
# 2  0.058966  0.073982  0.149235  0.251058  ...  0.042284  0.019171  0.008823
# 3  0.078777  0.034734  0.425358  0.043190  ...  0.020245  0.057756  0.021381
# 4  0.136346  0.008123  0.804749  0.076759  ...  0.006969  0.239036  0.002354
#
#          49                genre  popularity  release            artist  \
# ...

# %%
musicnn_data.shape
# Out:
# (109268, 57)

# %% [markdown]
# #### word2vec

# %%
word2vec_path = data_path + r"\word2vec.csv"
word2vec_data = pd.read_csv(word2vec_path)
word2vec_data.head()
# Out:
#                  id         0         1         2         3         4  \
# 0  710GxwapFWu6nZX9  0.012378  0.048408  0.001605  0.023883 -0.025053
# 1  0LiOzxBZ1aPLlFsK  0.031109  0.018026  0.022785  0.028802 -0.026084
# 2  JgqyXT3EFKz10FSz  0.027534  0.010042  0.010540  0.023234 -0.024125
# 3  mxzw6q1VfWMdd9ro  0.013538  0.026949  0.006707  0.026687 -0.028433
# 4  F4vPrkSvYHwgexdS  0.019174  0.025422  0.010472  0.029765 -0.015188
#
#           5         6         7         8  ...       296       297       298  \
# 0  0.004592  0.020611 -0.028692  0.040993  ... -0.012984 -0.014875  0.012971
# 1 -0.006278  0.030599 -0.041043  0.036703  ... -0.009981 -0.027846  0.021100
# 2  0.000474  0.020764 -0.051780  0.023568  ... -0.004652 -0.015556  0.019013
# 3 -0.010083  0.022415 -0.040218  0.033329  ...  0.016312 -0.021790  0.016149
# 4  0.007465  0.025536 -0.030486  0.026359  ... -0.012303 -0.011325  0.008986
#
#         299              genre  popularity  release              artist  \
# ...

# %%
word2vec_data.shape
# Out:
# (109269, 307)

# %% [markdown]
# #### vvg19

# %%
vgg19_path = data_path + r"\vgg19.tsv.bz2"
df = pd.read_csv(vgg19_path, sep="\t", compression="bz2")
