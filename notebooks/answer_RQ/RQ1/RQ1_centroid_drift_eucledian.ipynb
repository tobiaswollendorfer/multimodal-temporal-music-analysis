# %% [markdown]
# # RQ1 Answer: Modality-Dependent Temporal Genre Evolution (Euclidean Distance)
#
# **RQ1:** How much do music genres change over time across acoustic, visual, and lyrical feature modalities?
#
# This notebook is the Euclidean-distance inspection and interpretation notebook for RQ1. The calculation-heavy steps are expected to be done by:
#
# ```bash
# python src/04_answer_RQ1_calculate_drift.py
# ```
#
# The notebook loads the saved drift outputs, creates the main RQ1 plots and tables, and provides a compact structure for answering the research question.

# %% [markdown]
# ## Load Libraries And Paths

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

try:
    from helper_functions import PROCESSED_DIR
except ImportError:
    PROJECT_ROOT = Path.cwd()

    PROJECT_ROOT = PROJECT_ROOT.parent.parent.parent

    PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"

CENTROID_DIR = PROCESSED_DIR / "03_ortools_centroids"
DRIFT_DIR = PROCESSED_DIR / "04_ortools_centroid_drift"
PLOTS_DIR = PROJECT_ROOT / "plots" / "RQ1_answer"

PLOTS_DIR.mkdir(parents=True, exist_ok=True)

print("Centroid directory:", CENTROID_DIR)
print("Drift directory:", DRIFT_DIR)
print("Plots directory:", PLOTS_DIR)
# Out:
# Centroid directory: /home/tobias-wollendorfer/student1/master_thesis/multimodal-temporal-music-analysis/data/processed/03_ortools_centroids
# Drift directory: /home/tobias-wollendorfer/student1/master_thesis/multimodal-temporal-music-analysis/data/processed/04_ortools_centroid_drift
# Plots directory: /home/tobias-wollendorfer/student1/master_thesis/multimodal-temporal-music-analysis/plots/RQ1_answer

# %% [markdown]
# ## Load RQ1 Drift Outputs

# %%
drift_wpz = pd.read_parquet(
    DRIFT_DIR / "rq1_ortools_centroid_drift_wpz.parquet"
)

drift_wpz_neighbors = pd.read_parquet(
    DRIFT_DIR / "rq1_ortools_centroid_drift_wpz_neighbors.parquet"
)

drift_raw = pd.read_parquet(
    DRIFT_DIR / "rq1_ortools_centroid_drift_raw.parquet"
)

drift_raw_neighbors = pd.read_parquet(
    DRIFT_DIR / "rq1_ortools_centroid_drift_raw_neighbors.parquet"
)

modality_summary = pd.read_csv(
    DRIFT_DIR / "rq1_modality_drift_summary_wpz_neighbors.csv"
)

genre_drift_summary = pd.read_csv(
    DRIFT_DIR / "rq1_genre_drift_summary_wpz_neighbors.csv"
)

landscape_drift = pd.read_parquet(
    DRIFT_DIR / "rq1_selected_genre_landscape_drift_wpz_neighbors.parquet"
)

raw_vs_wpz_summary = pd.read_csv(
    DRIFT_DIR / "rq1_raw_vs_wpz_drift_summary.csv"
)

modalities = sorted(drift_wpz_neighbors["modality"].unique())

print("Modalities:", modalities)
print("WPZ neighboring transitions:", drift_wpz_neighbors.shape)
print("Raw neighboring transitions:", drift_raw_neighbors.shape)
# Out:
# Modalities: ['essentia', 'lyrics_tf_idf', 'mfcc', 'musicnn', 'vgg19', 'word2vec']
# WPZ neighboring transitions: (12670, 12)
# Raw neighboring transitions: (12670, 12)

# %% [markdown]
# ## Main RQ1 Summary Table

# %%
main_summary = modality_summary[
    [
        "modality",
        "n_transitions",
        "n_genres",
        "mean_euclidean_distance",
        "median_euclidean_distance",
        "std_euclidean_distance",
        "mean_cosine_distance",
        "median_cosine_distance",
        "median_tracks_t",
        "median_tracks_t1",
    ]
].copy()

main_summary = main_summary.sort_values(
    "mean_euclidean_distance",
    ascending=False,
)

main_summary
# Out:
#         modality  n_transitions  n_genres  mean_euclidean_distance  \
# 1          vgg19           2040        50                 8.123186
# 4       essentia           2126        50                 2.338798
# 0  lyrics_tf_idf           2126        50                 2.337153
# 2       word2vec           2126        50                 1.305929
# 3           mfcc           2126        50                 0.773923
# 5        musicnn           2126        50                 0.536921
#
#    median_euclidean_distance  std_euclidean_distance  mean_cosine_distance  \
# 1                   7.972392                1.598305              0.106170
# 4                   2.344472                0.455970              0.054254
# 0                   2.242259                0.566745              0.138956
# 2                   1.243031                0.297457              0.063515
# 3                   0.776803                0.214601              0.055637
# 5                   0.496839                0.173512              0.025686
#
#    median_cosine_distance  median_tracks_t  median_tracks_t1
# 1                0.110277             99.5             107.5
# 4                0.046670            112.0             116.0
# 0                0.144210            112.0             116.5
# 2                0.062850            112.0             116.5
# 3                0.047847            112.0             116.5
# 5                0.020989            112.0             116.5

# %% [markdown]
# ## Rank Modalities By Average Drift

# %%
ranking = main_summary[
    [
        "modality",
        "mean_euclidean_distance",
        "median_euclidean_distance",
        "mean_cosine_distance",
    ]
].reset_index(drop=True)

ranking.index = ranking.index + 1
ranking
# Out:
#         modality  mean_euclidean_distance  median_euclidean_distance  \
# 1          vgg19                 8.123186                   7.972392
# 2       essentia                 2.338798                   2.344472
# 3  lyrics_tf_idf                 2.337153                   2.242259
# 4       word2vec                 1.305929                   1.243031
# 5           mfcc                 0.773923                   0.776803
# 6        musicnn                 0.536921                   0.496839
#
#    mean_cosine_distance
# 1              0.106170
# 2              0.054254
# 3              0.138956
# 4              0.063515
# 5              0.055637
# 6              0.025686

# %% [markdown]
# ## Plot Mean Drift By Modality

# %%
plot_data = main_summary.sort_values("mean_euclidean_distance", ascending=True)

plt.figure(figsize=(8, 5))
plt.barh(
    plot_data["modality"],
    plot_data["mean_euclidean_distance"],
)
plt.xlabel("Mean Euclidean distance to next window")
plt.ylabel("Modality")
plt.title("RQ1: Average genre-level centroid drift by modality")
plt.tight_layout()

output_path = PLOTS_DIR / "rq1_average_drift_by_modality_euclidean.png"
plt.savefig(output_path, dpi=300, bbox_inches="tight")
print(output_path)

plt.show()
# Out:
# /home/tobias-wollendorfer/student1/master_thesis/multimodal-temporal-music-analysis/plots/RQ1_answer/rq1_average_drift_by_modality_euclidean.png

# %% [markdown]
# ## Plot Drift Distributions Across Modalities

# %%
ordered_modalities = main_summary["modality"].tolist()

boxplot_data = [
    drift_wpz_neighbors.loc[
        drift_wpz_neighbors["modality"] == modality,
        "euclidean_distance",
    ].dropna()
    for modality in ordered_modalities
]

plt.figure(figsize=(10, 5))
plt.boxplot(
    boxplot_data,
    labels=ordered_modalities,
    showfliers=False,
)
plt.ylabel("Euclidean distance to next window")
plt.title("RQ1: Genre-level drift distribution by modality")
plt.xticks(rotation=30, ha="right")
plt.tight_layout()

output_path = PLOTS_DIR / "rq1_drift_distribution_by_modality_euclidean.png"
plt.savefig(output_path, dpi=300, bbox_inches="tight")
print(output_path)

plt.show()
# Out:
# /tmp/ipykernel_1798123/708739747.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
# /home/tobias-wollendorfer/student1/master_thesis/multimodal-temporal-music-analysis/plots/RQ1_answer/rq1_drift_distribution_by_modality_euclidean.png

# %% [markdown]
# ## Plot Drift Over Time

# %%
# Calculate per-genre drift first, then weight genres equally.
genre_drift_over_time = (
    drift_wpz_neighbors
    .groupby(["modality", "window_start", "genre"], as_index=False)
    .agg(genre_mean_euclidean_distance=("euclidean_distance", "mean"))
)

drift_over_time = (
    genre_drift_over_time
    .groupby(["modality", "window_start"], as_index=False)
    .agg(
        mean_euclidean_distance=("genre_mean_euclidean_distance", "mean"),
        median_euclidean_distance=("genre_mean_euclidean_distance", "median"),
        n_genres=("genre", "nunique"),
    )
)

plt.figure(figsize=(12, 5))

for modality in ordered_modalities:
    data = drift_over_time[drift_over_time["modality"] == modality]

    plt.plot(
        data["window_start"],
        data["mean_euclidean_distance"],
        marker="o",
        markersize=3,
        label=modality,
    )

plt.xlabel("Window start")
plt.ylabel("Mean Euclidean distance to next window")
plt.title("RQ1: Mean genre-level centroid drift over time")
plt.legend()
plt.tight_layout()

output_path = PLOTS_DIR / "rq1_mean_drift_over_time_euclidean.png"
plt.savefig(output_path, dpi=300, bbox_inches="tight")
print(output_path)

plt.show()
# Out:
# /home/tobias-wollendorfer/student1/master_thesis/multimodal-temporal-music-analysis/plots/RQ1_answer/rq1_mean_drift_over_time_euclidean.png

# %% [markdown]
# ## Compare Genre Drift With Selected-Genre Landscape Baseline

# %%
genre_drift_by_window = (
    drift_wpz_neighbors
    .groupby(["modality", "window_start", "genre"], as_index=False)
    .agg(genre_mean_euclidean_distance=("euclidean_distance", "mean"))
)

genre_time = (
    genre_drift_by_window
    .groupby(["modality", "window_start"], as_index=False)
    .agg(mean_genre_euclidean_distance=("genre_mean_euclidean_distance", "mean"))
)

baseline_time = landscape_drift[
    ["modality", "window_start", "euclidean_distance"]
].rename(columns={"euclidean_distance": "landscape_euclidean_distance"})

baseline_comparison = genre_time.merge(
    baseline_time,
    on=["modality", "window_start"],
    how="left",
)

fig, axes = plt.subplots(2, 3, figsize=(16, 8), sharex=True)
axes = axes.flatten()

for ax, modality in zip(axes, modalities):
    data = baseline_comparison[
        baseline_comparison["modality"] == modality
    ].sort_values("window_start")

    ax.plot(
        data["window_start"],
        data["mean_genre_euclidean_distance"],
        label="Mean genre drift",
        linewidth=2,
    )
    ax.plot(
        data["window_start"],
        data["landscape_euclidean_distance"],
        label="Selected-genre landscape drift",
        linewidth=2,
        linestyle="--",
    )

    ax.set_title(modality)
    ax.set_xlabel("Window start")
    ax.set_ylabel("Euclidean distance")

axes[0].legend()
fig.suptitle("RQ1: Genre drift compared with selected-genre landscape drift")
plt.tight_layout()

output_path = PLOTS_DIR / "rq1_genre_drift_vs_landscape_baseline_euclidean.png"
plt.savefig(output_path, dpi=300, bbox_inches="tight")
print(output_path)

plt.show()
# Out:
# /home/tobias-wollendorfer/student1/master_thesis/multimodal-temporal-music-analysis/plots/RQ1_answer/rq1_genre_drift_vs_landscape_baseline_euclidean.png

# %% [markdown]
# ## Summarize Landscape Baseline Difference

# %%
baseline_summary = (
    baseline_comparison
    .groupby("modality")
    .agg(
        mean_genre_euclidean_distance=("mean_genre_euclidean_distance", "mean"),
        mean_landscape_euclidean_distance=("landscape_euclidean_distance", "mean"),
    )
    .reset_index()
)

baseline_summary["genre_minus_landscape"] = (
    baseline_summary["mean_genre_euclidean_distance"]
    - baseline_summary["mean_landscape_euclidean_distance"]
)

baseline_summary.sort_values("genre_minus_landscape", ascending=False)
# Out:
#         modality  mean_genre_euclidean_distance  \
# 4          vgg19                       8.550535
# 1  lyrics_tf_idf                       2.497875
# 0       essentia                       2.495770
# 5       word2vec                       1.409099
# 2           mfcc                       0.857743
# 3        musicnn                       0.604838
#
#    mean_landscape_euclidean_distance  genre_minus_landscape
# 4                           1.419339               7.131196
# 1                           1.126692               1.371183
# 0                           1.128387               1.367383
# 5                           1.100493               0.308606
# 2                           1.085672              -0.227929
# 3                           1.081405              -0.476567

# %% [markdown]
# ## Identify Highest-Drift Genres Per Modality

# %%
top_n = 10

top_drifting_genres = (
    genre_drift_summary
    .sort_values(
        ["modality", "mean_euclidean_distance"],
        ascending=[True, False],
    )
    .groupby("modality")
    .head(top_n)
    .reset_index(drop=True)
)

top_drifting_genres
# Out:
#          modality              genre  n_transitions  mean_cosine_distance  \
# 0        essentia         bossa nova             52              0.039617
# 1        essentia       experimental             51              0.110943
# 2        essentia     easy listening             44              0.065351
# 3        essentia          soft rock             48              0.102533
# 4        essentia          glam rock             34              0.112152
# 5        essentia            ambient             41              0.019752
# 6        essentia         electronic             44              0.056704
# 7        essentia        black metal             35              0.020488
# 8        essentia      hardcore punk             29              0.031507
# 9        essentia               folk             56              0.035447
# 10  lyrics_tf_idf          glam rock             34              0.190630
# 11  lyrics_tf_idf         bossa nova             52              0.145001
# 12  lyrics_tf_idf     brazilian rock             33              0.143420
# 13  lyrics_tf_idf     easy listening             44              0.172275
# 14  lyrics_tf_idf      hardcore punk             29              0.150122
# 15  lyrics_tf_idf          soft rock             48              0.183824
# 16  lyrics_tf_idf              samba             40              0.127832
# 17  lyrics_tf_idf        gothic rock             32              0.157472
# 18  lyrics_tf_idf               folk             56              0.161696
# 19  lyrics_tf_idf           synthpop             40              0.180968
# 20           mfcc         bossa nova             52              0.073588
# 21           mfcc       experimental             51              0.130452
# 22           mfcc               folk             56              0.067877
# 23           mfcc     easy listening             44              0.078788
# 24           mfcc               jazz             60              0.042809
# 25           mfcc             reggae             40              0.013846
# 26           mfcc           synthpop             40              0.112088
# 27           mfcc         electronic             44              0.049451
# 28           mfcc              blues             60              0.090513
# 29           mfcc          dream pop             33              0.093886
# 30        musicnn         soundtrack             42              0.026089
# 31        musicnn     easy listening             44              0.035080
# 32        musicnn            ambient             41              0.009499
# 33        musicnn         bossa nova             52              0.040043
# 34        musicnn       experimental             51              0.069603
# 35        musicnn               folk             56              0.028514
# 36        musicnn               jazz             60              0.021845
# 37        musicnn          dream pop             33              0.031175
# 38        musicnn           synthpop             40              0.008575
# 39        musicnn         electronic             44              0.011376
# 40          vgg19             grunge             31              0.185321
# 41          vgg19      hardcore punk             27              0.098054
# 42          vgg19              metal             41              0.093501
# 43          vgg19          glam rock             25              0.167317
# 44          vgg19          dream pop             33              0.121361
# 45          vgg19         bossa nova             44              0.139850
# 46          vgg19  progressive metal             31              0.093320
# 47          vgg19          soft rock             46              0.145967
# 48          vgg19       thrash metal             36              0.098251
# 49          vgg19     brazilian rock             32              0.120599
# 50       word2vec          glam rock             34              0.123065
# 51       word2vec         bossa nova             52              0.079985
# 52       word2vec     easy listening             44              0.085756
# 53       word2vec      hardcore punk             29              0.095190
# 54       word2vec          dream pop             33              0.140112
# 55       word2vec              disco             45              0.060100
# 56       word2vec         soundtrack             42              0.019558
# 57       word2vec          soft rock             48              0.064977
# 58       word2vec       experimental             51              0.073918
# 59       word2vec        gothic rock             32              0.078937
#
#     median_cosine_distance  mean_euclidean_distance  \
# 0                 0.032591                 3.305689
# 1                 0.086651                 3.163517
# 2                 0.047831                 2.913382
# 3                 0.077291                 2.911739
# 4                 0.099426                 2.892782
# 5                 0.012212                 2.846997
# 6                 0.020706                 2.826165
# 7                 0.011157                 2.804443
# 8                 0.021693                 2.795489
# 9                 0.023208                 2.791784
# 10                0.169853                 3.645915
# 11                0.136471                 3.428563
# 12                0.131967                 3.407072
# 13                0.177445                 3.283716
# 14                0.132921                 3.265623
# 15                0.171422                 3.146485
# 16                0.121549                 3.022349
# 17                0.145982                 2.980125
# 18                0.146325                 2.903416
# 19                0.175559                 2.766734
# 20                0.053427                 1.357577
# 21                0.091222                 1.187736
# 22                0.045704                 1.105328
# 23                0.072624                 1.091151
# 24                0.030264                 1.077852
# 25                0.010228                 1.050099
# 26                0.077511                 0.988383
# 27                0.021540                 0.959990
# 28                0.060214                 0.949672
# 29                0.053528                 0.941789
# 30                0.007343                 0.983522
# 31                0.027146                 0.872922
# 32                0.003341                 0.856511
# 33                0.030540                 0.848044
# 34                0.024341                 0.801725
# 35                0.012870                 0.784433
# 36                0.014864                 0.781090
# 37                0.016383                 0.733805
# 38                0.004799                 0.709085
# 39                0.002359                 0.679649
# 40                0.142931                12.440655
# 41                0.069000                10.665945
# 42                0.071982                10.452779
# 43                0.127646                10.408084
# 44                0.097401                10.255572
# 45                0.111104                 9.883538
# 46                0.068489                 9.748819
# 47                0.119472                 9.737030
# 48                0.080174                 9.632931
# 49                0.098767                 9.625406
# 50                0.117449                 1.876251
# 51                0.063230                 1.824240
# 52                0.081421                 1.789442
# 53                0.068217                 1.743596
# 54                0.111257                 1.742903
# 55                0.054245                 1.699900
# 56                0.003669                 1.683950
# 57                0.059728                 1.655590
# 58                0.026666                 1.642695
# 59                0.064646                 1.635745
#
#     median_euclidean_distance  median_tracks_t  median_tracks_t1
# 0                    3.310314             37.0              39.0
# 1                    2.718116             37.0              38.0
# 2                    2.750812             31.5              32.0
# 3                    2.734413             42.0              42.5
# 4                    2.879982             28.5              28.5
# 5                    2.538109            165.0             179.0
# 6                    1.862167            176.0             219.5
# 7                    2.334271            147.0             155.0
# 8                    2.527482             34.0              35.0
# 9                    2.631067             40.0              41.5
# 10                   3.485127             28.5              28.5
# 11                   3.449193             37.0              39.0
# 12                   3.227452             47.0              48.0
# 13                   3.142565             31.5              32.0
# 14                   3.164587             34.0              35.0
# 15                   3.007162             42.0              42.5
# 16                   2.722856             66.0              66.0
# 17                   2.847270             49.5              52.5
# 18                   3.125149             40.5              42.0
# 19                   2.686527             37.5              38.0
# 20                   1.269295             37.0              39.0
# 21                   1.003640             37.0              38.0
# 22                   0.930546             40.5              42.0
# 23                   1.042435             31.5              32.0
# 24                   0.955812             82.0              82.0
# 25                   0.946244             72.0              77.5
# 26                   0.827405             37.5              38.0
# 27                   0.654560            176.0             219.5
# 28                   0.846295             76.0              79.5
# 29                   0.832273             48.0              49.0
# 30                   0.904148            130.0             133.5
# 31                   0.837270             31.5              32.0
# 32                   0.598332            165.0             179.0
# 33                   0.815107             37.0              39.0
# 34                   0.609296             37.0              38.0
# 35                   0.578655             40.5              42.0
# 36                   0.699390             82.0              82.0
# 37                   0.619897             48.0              49.0
# 38                   0.667457             37.5              38.0
# 39                   0.416451            176.0             219.5
# 40                  11.439990            110.0             110.0
# 41                  10.174866             30.0              30.0
# 42                   8.395291             96.0             108.0
# 43                  10.047449             38.0              43.0
# 44                   9.695793             42.0              42.0
# 45                   9.459453             35.0              36.5
# 46                   8.580884             96.0              96.0
# 47                   9.106556             38.0              39.5
# 48                   8.482353            110.5             112.0
# 49                   9.325835             43.5              43.5
# 50                   1.900657             28.5              28.5
# 51                   1.647156             37.0              39.0
# 52                   1.641961             31.5              32.0
# 53                   1.545129             34.0              35.0
# 54                   1.768184             48.0              49.0
# 55                   1.567879             55.0              56.0
# 56                   1.316263            130.0             133.5
# 57                   1.594515             42.0              42.5
# 58                   1.490004             37.0              38.0
# 59                   1.522132             49.5              52.5

# %% [markdown]
# ## Plot Highest-Drift Genres For One Modality

# %%
selected_modality = "word2vec"
top_n = 15

plot_data = (
    genre_drift_summary[genre_drift_summary["modality"] == selected_modality]
    .sort_values("mean_euclidean_distance", ascending=True)
    .tail(top_n)
)

plt.figure(figsize=(8, 6))
plt.barh(plot_data["genre"], plot_data["mean_euclidean_distance"])
plt.xlabel("Mean Euclidean distance to next window")
plt.ylabel("Genre")
plt.title(f"RQ1: Highest average drift genres ({selected_modality})")
plt.tight_layout()

output_path = PLOTS_DIR / f"rq1_top_drifting_genres_euclidean_{selected_modality}.png"
plt.savefig(output_path, dpi=300, bbox_inches="tight")
print(output_path)

plt.show()
# Out:
# /home/tobias-wollendorfer/student1/master_thesis/multimodal-temporal-music-analysis/plots/RQ1_answer/rq1_top_drifting_genres_euclidean_word2vec.png

# %% [markdown]
# ## Check Whether Drift Is Driven By Few Extreme Genres

# %%
genre_variation = (
    genre_drift_summary
    .groupby("modality")
    .agg(
        mean_of_genre_means=("mean_euclidean_distance", "mean"),
        median_of_genre_means=("mean_euclidean_distance", "median"),
        p90_of_genre_means=("mean_euclidean_distance", lambda values: values.quantile(0.90)),
        max_of_genre_means=("mean_euclidean_distance", "max"),
    )
    .reset_index()
)

genre_variation["max_to_median_ratio"] = (
    genre_variation["max_of_genre_means"]
    / genre_variation["median_of_genre_means"]
)

genre_variation.sort_values("mean_of_genre_means", ascending=False)
# Out:
#         modality  mean_of_genre_means  median_of_genre_means  \
# 4          vgg19             8.123186               7.972392
# 0       essentia             2.338798               2.344472
# 1  lyrics_tf_idf             2.337153               2.242259
# 5       word2vec             1.305929               1.243031
# 2           mfcc             0.773923               0.776803
# 3        musicnn             0.536921               0.496839
#
#    p90_of_genre_means  max_of_genre_means  max_to_median_ratio
# 4            9.920742           12.440655             1.560467
# 0            2.851576            3.305689             1.409993
# 1            3.158399            3.645915             1.626001
# 5            1.704200            1.876251             1.509416
# 2            1.052875            1.357577             1.747647
# 3            0.786163            0.983522             1.979560

# %% [markdown]
# ## Compare Raw And Within-Period Normalized Drift

# %%
raw_vs_wpz_summary[
    [
        "modality",
        "wpz_mean_euclidean_distance",
        "wpz_median_euclidean_distance",
        "raw_mean_euclidean_distance",
        "raw_median_euclidean_distance",
        "wpz_mean_cosine_distance",
        "raw_mean_cosine_distance",
    ]
].sort_values("wpz_mean_euclidean_distance", ascending=False)
# Out:
#         modality  wpz_mean_euclidean_distance  wpz_median_euclidean_distance  \
# 4          vgg19                     8.123186                       7.972392
# 0       essentia                     2.338798                       2.344472
# 1  lyrics_tf_idf                     2.337153                       2.242259
# 5       word2vec                     1.305929                       1.243031
# 2           mfcc                     0.773923                       0.776803
# 3        musicnn                     0.536921                       0.496839
#
#    raw_mean_euclidean_distance  raw_median_euclidean_distance  \
# 4                     7.891632                       6.967401
# 0                145670.192883                   80367.377169
# 1                     0.067959                       0.060119
# 5                     0.017987                       0.015515
# 2                    17.155774                      14.223112
# 3                     0.037926                       0.031194
#
#    wpz_mean_cosine_distance  raw_mean_cosine_distance
# 4                  0.106170                  0.004640
# 0                  0.054254                  0.001970
# 1                  0.138956                  0.041745
# 5                  0.063515                  0.001605
# 2                  0.055637                  0.001099
# 3                  0.025686                  0.002663

# %% [markdown]
# ## Notes And Limitations
#
# - The main comparison uses within-period z-normalized centroids and Euclidean distance, so the result describes the magnitude of relative genre movement within the feature distribution of the same period.
# - Euclidean distance captures changes in feature profile direction. Euclidean distance also captures displacement magnitude and is more sensitive to feature dimensionality.
# - The analysis uses neighboring sliding windows with one-year hops. For statistical testing, non-overlapping windows or temporal-dependence-aware methods should be used.
# - VGG19 may have slightly lower coverage than the other modalities because visual features are not available for all tracks.
# - The selected-genre landscape baseline is based on the OR-Tools selected genre set, not the complete track-level dataset.
