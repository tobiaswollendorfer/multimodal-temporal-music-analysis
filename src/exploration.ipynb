# %%
import pandas as pd

# %%
data = pd.read_parquet("../data/processed/musicnn_centroids_wpz_windowed.parquet")

# %%
data
# Out:
#                   genre modality  window_start  window_end window_label  \
# 0                  jazz  musicnn          1951        1955    1951_1955
# 1                  jazz  musicnn          1952        1956    1952_1956
# 2                  jazz  musicnn          1953        1957    1953_1957
# 3                  jazz  musicnn          1954        1958    1954_1958
# 4                 blues  musicnn          1955        1959    1955_1959
# ...                 ...      ...           ...         ...          ...
# 3298  singer-songwriter  musicnn          2019        2023    2019_2023
# 3299               soul  musicnn          2019        2023    2019_2023
# 3300         soundtrack  musicnn          2019        2023    2019_2023
# 3301           synthpop  musicnn          2019        2023    2019_2023
# 3302       thrash metal  musicnn          2019        2023    2019_2023
#
#       n_tracks         0         1         2         3  ...        40  \
# ...
