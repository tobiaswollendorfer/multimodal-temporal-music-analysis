# %%
import pandas as pd

# %%
dataset_centroid = pd.read_parquet("../data/processed/04_centroid_drift/centroid_drift_wpz_neighbors.parquet")
dataset_gaussian = pd.read_parquet("../data/processed/06_gaussian_distribution_drift/gaussian_w2_drift_wpz_neighbors.parquet")

# %%
dataset_centroid
# Out:
#        modality              genre  window_start  window_end  \
# 0      essentia  alternative metal          1995        1999
# 1      essentia  alternative metal          1996        2000
# 2      essentia  alternative metal          1997        2001
# 3      essentia  alternative metal          1998        2002
# 4      essentia  alternative metal          1999        2003
# ...         ...                ...           ...         ...
# 18263     vgg19        witch house          2012        2016
# 18264     vgg19        witch house          2013        2017
# 18265     vgg19        witch house          2014        2018
# 18266     vgg19            worship          2014        2018
# 18267     vgg19            worship          2015        2019
#
#        next_window_start  next_window_end  window_gap  n_tracks_t  \
# 0                   1996             2000           1          21
# 1                   1997             2001           1          22
# ...

# %%
dataset_gaussian
# Out:
#        modality              genre  window_start  window_end  \
# 0      essentia  alternative metal          1997        2001
# 1      essentia  alternative metal          1998        2002
# 2      essentia  alternative metal          1999        2003
# 3      essentia  alternative metal          2000        2004
# 4      essentia  alternative metal          2001        2005
# ...         ...                ...           ...         ...
# 14908     vgg19        witch house          2010        2014
# 14909     vgg19        witch house          2011        2015
# 14910     vgg19        witch house          2012        2016
# 14911     vgg19        witch house          2013        2017
# 14912     vgg19        witch house          2014        2018
#
#        next_window_start  next_window_end  window_gap  n_tracks_t  \
# 0                   1998             2002           1          34
# 1                   1999             2003           1          51
# ...
